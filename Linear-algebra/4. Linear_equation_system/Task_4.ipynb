# %% [markdown]
# # Урок 4. Системы линейных уравнений
# ## Методический материал 1

# %%
import numpy as np
from numpy import linalg

# %% [markdown]
# #### Задание 1
# Решить систему уравнений методом Гаусса:
#
# $\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4
# \end{cases}$
#
# __Решение:__
#
# Запишем систему в виде матрицы:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Вычитаем из 3-й строки 1-ю:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Вычитаем из 2-й строки 1-ю два раза:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Из полученной системы послеовательно находим значения неизвестных от $x_{n}$ до $x_{1}$ по формулам:
#
# $x_{k}=b'_{k}-a'_{kk+1}x_{k+1}-...-a'_{kn}x_{n}.$
#
# $x_{4}=c,$<br>
# $-2x_{3}+3c=4 \; \Leftrightarrow \; x_{3}=(3c-4)/2,$<br>
# $-x_{2} + (3c-4)/2 + 5c= -2 \; \Leftrightarrow \; x_{2}=13c/2,$<br>
# $x_{1} + 13c/2 - (3c-4)/2 -2c= 0 \; \Leftrightarrow \; x_{1}=-3c-2.$

# %% [markdown]
# ---
# #### Задание 2
# Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5
# \end{cases}$
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2
# \end{cases}$
#
# Система, не имеющая решений, называется _несовместной_. Соответственно, если система имеет хотя бы одно решение, она называется _совместной_. При этом, если это решение единственное, она называется _определенной_, а если решений больше одного — _неопределенной_.
#
# #### Теорема Кронекера — Капелли
#
# Вернемся к матричному виду систем линейных уравнений
#
# $$Ax=b.$$
#
# __Теорема__
#
# Необходимым и достаточным условием совместности системы из $m$ уравнений с $n$ неизвестными является равенство между собой рангов матрицы коэффициентов $A$ и расширенной матрицы $\tilde A$
#
# $$rank A=rank \tilde A.$$
#
# Причем:<br>
# 1) если $rankA=rank \tilde A=n$, где $n$ — число неизвестных, то система определена, т. е. имеет единственное решение;<br>
# 2) если $rankA=rank \tilde A<n$, то система имеет бесконечное количество решений;<br>
# 3) если $rankA<rank \tilde A$, то система несовместна.

# %% [markdown]
# __Решение:__
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3} = 0
# \end{cases}$
#
# Запишем систему в виде матрицы:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 2 & -5 & -3\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$
#
# Найдём ранг матрицы:
#
# От 2-й строки вычитаем два раза 3-ю строку:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 0 & -7 & -1\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$
#
# От 1-й строки вычитаем 3-ю 3 раза и меняем их местами:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & -7 & -1\\
# 0 & -4 & 4
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -17\\
# 4
# \end{matrix}
# \end{pmatrix}$
#
# Делим 3-ю строку на -4 и меняем местами с 2-й строкой:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & 1 & -1\\
# 0 & -7 & -1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -1\\
# -17
# \end{matrix}
# \end{pmatrix}$
#
# Складываем 3-ю строку с 2-й 7 раз:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & 1 & -1\\
# 0 & 0 & -8
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -1\\
# -24
# \end{matrix}
# \end{pmatrix}$
#
# __Ответ:__ Ранг матрицы равен 3, значит, по теореме Капелли - система определена и имеет единственное решение.
#
# **Выполним проверку через Nump:**

# %%
A = np.array([[3, -1, 1, 4], [2, -5, -3, -17], [1, 1, -1, 0]])
linalg.matrix_rank(A)
# Out:
# 3

# %% [markdown]
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5
# \end{cases}$
#
# Запишем систему в виде матрицы:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}$
#
# Найдём ранг матрицы:
#
# Складываем 2-ю строку с 1-й строкой:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 3 & -6 & 9\\
# 3 & -6 & 9
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -1\\
# 5
# \end{matrix}
# \end{pmatrix}$
#
# Вычитаем из 3-й строки 2-ю строку:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 3 & -6 & 9\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -1\\
# 6
# \end{matrix}
# \end{pmatrix}$
#
# __Ответ:__ Ранг матрицы равен 2, значит, по теореме Капелли - система несовместа.
#
# **Выполним проверку через Numpy:**

# %%
A = np.array([[2, -4, 6, 1], [1, -2, 3, -2], [3, -6, 9, 5]])
linalg.matrix_rank(A)
# Out:
# 2

# %% [markdown]
# Системы уравнений, в которых число уравнений меньше числа неизвестных, называются _недоопределенными_.
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2
# \end{cases}$
#
# Запишем систему в виде матрицы:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5\\
# 3 & 1 & -8
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -2
# \end{matrix}
# \end{pmatrix}$
#
# Вычитаем от второй строки первую 3 раза:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5\\
# 0 & -5 & -23
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -14
# \end{matrix}
# \end{pmatrix}$
#
# __Ответ:__ Так как есть один, свободный член, через который мы можем выразить все остальные - это значит что система определена и имеет бесконечное количество решений.

# %% [markdown]
# ---
# #### Задание 3
# Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}$
#
# __Ответ:__ Ранг матрицы равен 4, значит, по теореме Капелли - система определена и имеет единственное решение.
#
# **Выполним проверку через Nump:**

# %%
A = np.array([[1, 3, -2, 4, 3], [0, 5, 0, 1, 2], [0, 0, 3, 0, 4], [0, 0, 0, 2, 1]])
linalg.matrix_rank(A)
# Out:
# 4

# %% [markdown]
# ---
# #### Задание 4
# Дана система линейных уравнений, заданная расширенной матрицей
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}$
#
# Отнимем от 2-й строки 1-ю 4 раза и от 3-й строки 1-ю 7 раз:
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & -6 & -12
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4a\\
# c-7a
# \end{matrix}
# \end{pmatrix}$
#
# Для несовместности системы, необходимо, чтобы два последних свободынх члена не были подобные. Подобие определяется коэффициетом строки. Строка 2 и 3 подобные, так как коэффициент подобия равен 2. Для нахождения соотношения между параметрами по условию задачи, требуется $2b - c \ne a$.

# %% [markdown]
# ##  Методический материал 2
# #### Задание 1
# Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
# __Решение:__
#
# $det A = \begin{vmatrix}
# 1 & -2\\
# 3 & -4
# \end{vmatrix} = 2$
#
# $det_1 = \begin{vmatrix}
# 1 & -2\\
# 7 & -4
# \end{vmatrix} = 10$
#
# $det_2 = \begin{vmatrix}
# 1 & 1\\
# 3 & 7
# \end{vmatrix} = 4$
#
# Поиск корней:
#
# $x_1 = \frac{det_1}{det A} = \frac{10}{2} = 5$
#
# $x_2 = \frac{det_2}{det A} = \frac{4}{2} = 2$
#
# __Ответ:__ $x_1 = 5, x_2 = 2$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
